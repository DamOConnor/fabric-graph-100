-- %% [markdown]
-- # Graph tutorials

-- %% [markdown]
-- ## Wikipedia Example
-- https://en.wikipedia.org/wiki/Graph_(discrete_mathematics)

-- %% [markdown]
-- ![image-alt-text](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5b/6n-graf.svg/500px-6n-graf.svg.png)

-- %%
DROP TABLE IF EXISTS nod_numbers;
CREATE TABLE nod_numbers ( number INT, name VARCHAR(10), Type VARCHAR(10) );

DROP TABLE IF EXISTS edg_numbers;
CREATE TABLE edg_numbers ( fromNumber INT, toNumber INT );

INSERT INTO nod_numbers ( number, name )
VALUES ( 1, 'One' ), ( 2, 'Two' ), ( 3, 'Three' ), ( 4, 'Four' ), ( 5, 'Five' ), ( 6, 'Six' );

INSERT INTO edg_numbers ( fromNumber, toNumber )
VALUES ( 1, 2 ), ( 1, 5 ), ( 2, 3 ), ( 2, 5 ), ( 3, 4 ), ( 4, 6 );


UPDATE nod_numbers
SET type = 'number';
-- Out:
-- StatementMeta(, d9de254b-e82f-464a-b879-1b3d74dc991a, 8, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 1 rows and 1 fields>

-- %%
SELECT * FROM nod_numbers;
-- Out:
-- StatementMeta(, d9de254b-e82f-464a-b879-1b3d74dc991a, 9, Finished, Available, Finished)
-- <Spark SQL result set with 6 rows and 3 fields>

-- %% [markdown]
-- **NB** This cell is frozen.  Optionally unfreeze and run it during lab 1 to add the missing connection.

-- %%
INSERT INTO edg_numbers ( fromNumber, toNumber )
VALUES ( 4, 5 );
-- Out:
-- StatementMeta(, 9a2b00f1-ae29-479c-ac75-de183a2e58a1, 4, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>

-- %%
SELECT * FROM edg_numbers ORDER BY 1, 2;
-- Out:
-- StatementMeta(, d9de254b-e82f-464a-b879-1b3d74dc991a, 10, Finished, Available, Finished)
-- <Spark SQL result set with 6 rows and 2 fields>

-- %% [markdown]
-- ## Weighted graph
-- A weighted graph or a network is a graph in which a number (the weight) is assigned to each edge.  Such weights might represent for example costs, lengths or capacities, depending on the problem at hand. Such graphs arise in many contexts, for example in shortest path problems such as the traveling salesman problem.

-- %% [markdown]
-- ![Weighted graph](https://upload.wikimedia.org/wikipedia/commons/f/f0/Weighted_network.svg)

-- %% [markdown]
-- Imagine the nodes are lettered `a` to `j` from left to right.

-- %%
DROP TABLE IF EXISTS nod_letters;
CREATE TABLE nod_letters ( letters CHAR(1) );

DROP TABLE IF EXISTS edg_letters;
CREATE TABLE edg_letters ( fromLetter CHAR(1), toLetter CHAR(1), weight INT );

INSERT INTO nod_letters ( letters )
VALUES ( 'a' ), ( 'b' ), ( 'c' ), ( 'd' ), ( 'e' ), ( 'f' ), ( 'g' ), ( 'h' ), ( 'i' ), ( 'j' );

INSERT INTO edg_letters ( fromLetter, toLetter, weight )
VALUES ( 'a', 'b', 4 ), ( 'a', 'c', 4 ), ( 'b', 'c', 2 ), ( 'b', 'e', 1 ), ( 'c', 'd', 1 ), ( 'd', 'f', 4 ), ( 'e', 'f', 2 ), ( 'e', 'g', 1 ), ( 'g', 'i', 3 ), ( 'i', 'h', 3 ), ( 'i', 'j', 2 ), ( 'h', 'j', 4 );
-- Out:
-- StatementMeta(, d9de254b-e82f-464a-b879-1b3d74dc991a, 28, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>

-- %% [markdown]
-- ## Social Network
-- https://github.com/graphframes/graphframes

-- %%
DROP TABLE IF EXISTS nod_person;
CREATE TABLE nod_person ( personId INT, name VARCHAR(10), age INT );

DROP TABLE IF EXISTS edg_follows;
CREATE TABLE edg_follows ( src INT, dst INT, relationship VARCHAR(10) );

INSERT INTO nod_person ( personId, name, age )
VALUES ( 1, 'Alice', 30 ), ( 2, 'Bob', 25 ), ( 3, 'Charlie', 35 );

INSERT INTO edg_follows ( src, dst, relationship )
VALUES ( 1, 2, 'friend' ), ( 2, 1, 'friend' ), ( 2, 3, 'friend' ), ( 3, 2, 'enemy' );
-- Out:
-- StatementMeta(, d9de254b-e82f-464a-b879-1b3d74dc991a, 22, Finished, Available, Finished)
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
-- <Spark SQL result set with 0 rows and 0 fields>
